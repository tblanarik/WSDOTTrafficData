# %% [markdown]
# # DataViewer
# A Jupyter Notebook for visualizing the data
#
# Note: The data is stored assuming UTC timezone, however most of these functions take the parameter `local_tz`, allowing you to convert to the timezone of your choice. The default value of `local_tz` is US/Pacific.

# %%
# %matplotlib notebook

# %%
import sys
sys.path.append('../')

# %%
import traffic.dbutil as dbutil
import traffic.plotting as tp
import traffic.travel as travel
import traffic.weather as weather

# %%
weather.get_seattle_weather('2018-05-19')
# Out:
#   attributes datatype                 date            station  value
# 0   ,,W,2400     PRCP  2018-05-19T00:00:00  GHCND:USW00024233   0.04
# 1      H,,S,     TAVG  2018-05-19T00:00:00  GHCND:USW00024233  60.00
# 2   ,,W,2400     TMAX  2018-05-19T00:00:00  GHCND:USW00024233  72.00
# 3   ,,W,2400     TMIN  2018-05-19T00:00:00  GHCND:USW00024233  45.00

# %%
df = dbutil.get_travel_times(26, '2018-05-14')
df = travel.filter_for_weekdays(df)
df = travel.filter_hour_range(df, 13, 19)

# %%
df.describe()
# Out:
#        CurrentTime
# count   105.000000
# mean     34.876190
# std      14.292746
# min      15.000000
# 25%      24.000000
# 50%      32.000000
# 75%      42.000000
# max      79.000000

# %%
canvas = tp.canvas_from_data(df)

# %%
canvas.figure
