# %% [markdown]
# # DataViewer
# A Jupyter Notebook for visualizing the data
#
# Note: The data is stored assuming UTC timezone, however most of these functions take the parameter `local_tz`, allowing you to convert to the timezone of your choice. The default value of `local_tz` is US/Pacific.

# %%
# %matplotlib notebook

# %%
import sys
sys.path.append('../')

# %%
import traffic.dbutil as dbutil
import traffic.plotting as tp
import traffic.travel as travel
import traffic.weather as weather

# %%
weather.get_seattle_weather('2018-05-19')
# Out:
#   attributes datatype                 date            station  value
# 0   ,,W,2400     PRCP  2018-05-19T00:00:00  GHCND:USW00024233   0.04
# 1      H,,S,     TAVG  2018-05-19T00:00:00  GHCND:USW00024233  60.00
# 2   ,,W,2400     TMAX  2018-05-19T00:00:00  GHCND:USW00024233  72.00
# 3   ,,W,2400     TMIN  2018-05-19T00:00:00  GHCND:USW00024233  53.00

# %%
df = dbutil.get_travel_times(26, '2018-05-14')
df = travel.filter_for_weekdays(df)
df = travel.filter_hour_range(df, 13, 19)
# Out:
# ..\traffic\dbutil.py:52: FutureWarning: 'TimeUpdated' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#   return df.set_index(pandas.DatetimeIndex(df['TimeUpdated'])).sort_values(by=['TimeUpdated'])

# %%
df = dbutil.get_travel_times(26, '2019-02-03', '2019-02-09')

# %%
df = travel.filter_for_weekdays(df)

# %%
df = travel.filter_hour_range(df, 13, 19)

# %%
df.describe()
# Out:
#        CurrentTime
# count   105.000000
# mean     23.466667
# std      15.749278
# min      15.000000
# 25%      15.000000
# 50%      17.000000
# 75%      25.000000
# max      92.000000

# %%
import matplotlib.pyplot as plt
from matplotlib.figure import Figure
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
from matplotlib.dates import DateFormatter
import dateutil
import pandas

# %%
importlib.reload(tp)
# Out:
# <module 'traffic.plotting' from '..\\traffic\\plotting.py'>

# %%
df = df.sort_values(by=['TimeUpdated'])

# %%
canvas = tp.canvas_from_data(df)

# %%
canvas.figure

# %%
df
# Out:
#                   TimeUpdated  CurrentTime                   Description
# 113 2019-02-04 13:15:00-08:00           17  Lynnwood to Downtown Seattle
# 114 2019-02-04 13:35:00-08:00           17  Lynnwood to Downtown Seattle
# 115 2019-02-04 13:55:00-08:00           16  Lynnwood to Downtown Seattle
# 116 2019-02-04 14:15:00-08:00           15  Lynnwood to Downtown Seattle
# 117 2019-02-04 14:35:00-08:00           18  Lynnwood to Downtown Seattle
# 118 2019-02-04 14:55:00-08:00           16  Lynnwood to Downtown Seattle
# 119 2019-02-04 15:15:00-08:00           16  Lynnwood to Downtown Seattle
# 120 2019-02-04 15:35:00-08:00           17  Lynnwood to Downtown Seattle
# 121 2019-02-04 15:55:00-08:00           15  Lynnwood to Downtown Seattle
# 122 2019-02-04 16:15:00-08:00           16  Lynnwood to Downtown Seattle
# 123 2019-02-04 16:35:00-08:00           15  Lynnwood to Downtown Seattle
# 124 2019-02-04 16:55:00-08:00           15  Lynnwood to Downtown Seattle
# 189 2019-02-05 14:35:00-08:00           16  Lynnwood to Downtown Seattle
# 190 2019-02-05 14:55:00-08:00           20  Lynnwood to Downtown Seattle
# 191 2019-02-05 15:15:00-08:00           17  Lynnwood to Downtown Seattle
# 192 2019-02-05 15:35:00-08:00           18  Lynnwood to Downtown Seattle
# 194 2019-02-05 15:55:00-08:00           17  Lynnwood to Downtown Seattle
# ..                        ...          ...                           ...
# 310 2019-02-07 17:15:00-08:00           22  Lynnwood to Downtown Seattle
# 312 2019-02-07 17:35:00-08:00           18  Lynnwood to Downtown Seattle
# 313 2019-02-07 17:55:00-08:00           17  Lynnwood to Downtown Seattle
# 314 2019-02-07 18:15:00-08:00           17  Lynnwood to Downtown Seattle
# 315 2019-02-07 18:35:00-08:00           17  Lynnwood to Downtown Seattle
# 316 2019-02-07 18:55:00-08:00           16  Lynnwood to Downtown Seattle
# 317 2019-02-07 19:15:00-08:00           15  Lynnwood to Downtown Seattle
# 318 2019-02-07 19:35:00-08:00           15  Lynnwood to Downtown Seattle
# 319 2019-02-07 19:55:00-08:00           16  Lynnwood to Downtown Seattle
# 369 2019-02-08 13:15:00-08:00           70  Lynnwood to Downtown Seattle
# 370 2019-02-08 13:35:00-08:00           80  Lynnwood to Downtown Seattle
# 371 2019-02-08 13:55:00-08:00           92  Lynnwood to Downtown Seattle
# 372 2019-02-08 14:15:00-08:00           85  Lynnwood to Downtown Seattle
# 373 2019-02-08 14:35:00-08:00           81  Lynnwood to Downtown Seattle
# 374 2019-02-08 14:55:00-08:00           72  Lynnwood to Downtown Seattle
# 375 2019-02-08 15:15:00-08:00           59  Lynnwood to Downtown Seattle
# 376 2019-02-08 15:35:00-08:00           36  Lynnwood to Downtown Seattle
# 377 2019-02-08 15:55:00-08:00           19  Lynnwood to Downtown Seattle
# 378 2019-02-08 16:15:00-08:00           15  Lynnwood to Downtown Seattle
# 379 2019-02-08 16:35:00-08:00           15  Lynnwood to Downtown Seattle
# 380 2019-02-08 16:55:00-08:00           15  Lynnwood to Downtown Seattle
# 381 2019-02-08 17:15:00-08:00           15  Lynnwood to Downtown Seattle
# 382 2019-02-08 17:35:00-08:00           15  Lynnwood to Downtown Seattle
# 383 2019-02-08 17:55:00-08:00           15  Lynnwood to Downtown Seattle
# 384 2019-02-08 18:15:00-08:00           15  Lynnwood to Downtown Seattle
# 385 2019-02-08 18:35:00-08:00           15  Lynnwood to Downtown Seattle
# 386 2019-02-08 18:55:00-08:00           15  Lynnwood to Downtown Seattle
# 387 2019-02-08 19:15:00-08:00           15  Lynnwood to Downtown Seattle
# 388 2019-02-08 19:35:00-08:00           15  Lynnwood to Downtown Seattle
# 389 2019-02-08 19:55:00-08:00           15  Lynnwood to Downtown Seattle
#
# [105 rows x 3 columns]

# %%
query = "SELECT * FROM TravelTimes WHERE TIMEUPDATED BETWEEN '{1}' AND '{2}'".format('','')
